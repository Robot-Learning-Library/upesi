# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Training data normalization

# %%
env = 'pandaopendoor'
prefix=env+'/'
raw_data = np.load(prefix+'dynamics.npy', allow_pickle=True)
print(raw_data.shape)
# Out:
# (3000000, 2)

# %%
# mean and std of param before normalization
param_data = np.vstack(np.vstack(raw_data[:, 0])[:, -1])
print(param_data.shape)
norm_factor = []
m_vec = []
std_vec = []
for dim in range(param_data.shape[1]):
    m=np.mean(param_data.T[dim])
    std=np.std(param_data.T[dim])
    m_vec.append(m)
    std_vec.append(std)
m_vec = np.array(m_vec)
std_vec = np.array(std_vec)
norm_factor=[m_vec, std_vec]
np.save(prefix+'norm_factor.npy', norm_factor)
print(norm_factor)

# mean and std of s before normalization
s_data = np.vstack(np.vstack(raw_data[:, 0])[:, 0])
print(s_data.shape)
s_norm_factor = []
s_m_vec = []
s_std_vec = []
for dim in range(s_data.shape[1]):
    m=np.mean(s_data.T[dim])
    std=np.std(s_data.T[dim])
    s_m_vec.append(m)
    s_std_vec.append(std)
s_m_vec = np.array(s_m_vec)
s_std_vec = np.array(s_std_vec)
s_norm_factor=[s_m_vec, s_std_vec]
np.save(prefix+'norm_factor_s.npy', s_norm_factor)
print(s_norm_factor)

# mean and std of s_ before normalization
s__data = np.vstack(raw_data[:, 1])
print(s__data.shape)
s__norm_factor = []
s__m_vec = []
s__std_vec = []
for dim in range(s__data.shape[1]):
    m=np.mean(s__data.T[dim])
    std=np.std(s__data.T[dim])
    s__m_vec.append(m)
    s__std_vec.append(std)
s__m_vec = np.array(s__m_vec)
s__std_vec = np.array(s__std_vec)
s__norm_factor=[s__m_vec, s__std_vec]
np.save(prefix+'norm_factor_s_.npy', s__norm_factor)
print(s_norm_factor)
# Out:
# /home/quantumiracle/anaconda3/envs/rlgpu/lib/python3.7/site-packages/numpy/core/shape_base.py:121: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# (3000000, 20)
# [array([1.00032426e-01, 9.99815017e-02, 9.99957845e-02, 1.00418597e-01,
#        1.00372262e-01, 1.00028450e-02, 1.00849690e-02, 2.48040274e-01,
#        2.51164049e-01, 2.45028690e-01, 2.47608066e-01, 2.52690077e-01,
#        2.47275919e-01, 2.54883468e-01, 9.00162101e-01, 4.47824538e-01,
#        1.98954388e-01, 5.01874566e-01, 1.00441315e+02, 5.98226881e+00],
#       dtype=float32), array([2.3029815e-02, 2.3088746e-02, 2.3277063e-02, 2.2916501e-02,
#        2.2743544e-02, 2.3018920e-03, 2.3018862e-03, 1.4486979e-01,
#        1.4208618e-01, 1.4465690e-01, 1.4257348e-01, 1.4242844e-01,
#        1.4382720e-01, 1.4421144e-01, 5.7949468e-02, 2.0267838e-01,
#        5.7753969e-02, 2.9034409e-01, 2.8754414e+01, 2.3220284e+00],
#       dtype=float32)]
# (3000000, 25)
# [array([-6.08897429e-01, -7.65844612e-02,  1.37673751e+00, -1.18251617e-04,
#        -5.80692092e-04, -2.53560216e-03, -2.27889830e+00,  4.11621631e-01,
#        -6.28904473e-01, -1.84162286e+00,  1.37842752e+00,  3.56974438e+00,
#        -6.29698741e-01, -6.40422125e-03,  3.96812592e-03,  7.82355833e-03,
#        -3.07340178e-03, -8.46061207e-03,  7.07735239e-03,  1.59033324e-03,
#         3.76270561e-02, -7.25100544e-02,  3.17693039e-02, -4.87375145e-02,
#        -2.64453585e-01]), array([0.01916555, 0.02746968, 0.03150463, 0.00541949, 0.0071902 ,
#        0.0097609 , 0.07927402, 0.0530436 , 0.14187929, 0.06416701,
#        0.1386652 , 0.22756696, 0.05702748, 0.01341492, 0.02025438,
#        0.01519972, 0.01733467, 0.01938022, 0.02443716, 0.02079639,
#        0.00579951, 0.01660029, 0.01275078, 0.03150463, 0.14931493])]
# (3000000, 25)
# [array([-6.08897429e-01, -7.65844612e-02,  1.37673751e+00, -1.18251617e-04,
#        -5.80692092e-04, -2.53560216e-03, -2.27889830e+00,  4.11621631e-01,
#        -6.28904473e-01, -1.84162286e+00,  1.37842752e+00,  3.56974438e+00,
#        -6.29698741e-01, -6.40422125e-03,  3.96812592e-03,  7.82355833e-03,
#        -3.07340178e-03, -8.46061207e-03,  7.07735239e-03,  1.59033324e-03,
#         3.76270561e-02, -7.25100544e-02,  3.17693039e-02, -4.87375145e-02,
#        -2.64453585e-01]), array([0.01916555, 0.02746968, 0.03150463, 0.00541949, 0.0071902 ,
#        0.0097609 , 0.07927402, 0.0530436 , 0.14187929, 0.06416701,
#        0.1386652 , 0.22756696, 0.05702748, 0.01341492, 0.02025438,
#        0.01519972, 0.01733467, 0.01938022, 0.02443716, 0.02079639,
#        0.00579951, 0.01660029, 0.01275078, 0.03150463, 0.14931493])]

# %%
# normalize the data with calculated mean and std
processed_data = raw_data.copy()
for i in range(processed_data.shape[0]):
    if i % 5000 ==0:
        print(i)
    processed_data[i][0][-1] = ((processed_data[i][0][-1] - m_vec)/std_vec).tolist() # param norm
    processed_data[i][0][0] = ((processed_data[i][0][0] - s_m_vec)/s_std_vec).tolist() # s norm
    processed_data[i][1] = ((processed_data[i][1] - s__m_vec)/s__std_vec).tolist() # s_ norm
print(processed_data.shape)
np.save(prefix+'norm_dynamics.npy', processed_data)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000
# 100000
# 105000
# 110000
# 115000
# 120000
# 125000
# 130000
# 135000
# 140000
# 145000
# 150000
# 155000
# 160000
# 165000
# 170000
# 175000
# 180000
# 185000
# 190000
# 195000
# 200000
# 205000
# 210000
# 215000
# 220000
# 225000
# 230000
# 235000
# 240000
# 245000
# 250000
# 255000
# 260000
# 265000
# 270000
# 275000
# 280000
# 285000
# 290000
# 295000
# 300000
# 305000
# 310000
# 315000
# 320000
# 325000
# 330000
# 335000
# 340000
# 345000
# 350000
# 355000
# 360000
# 365000
# 370000
# 375000
# 380000
# 385000
# 390000
# 395000
# 400000
# 405000
# 410000
# 415000
# 420000
# 425000
# 430000
# 435000
# 440000
# 445000
# 450000
# 455000
# 460000
# 465000
# 470000
# 475000
# 480000
# 485000
# 490000
# 495000
# 500000
# 505000
# 510000
# 515000
# 520000
# 525000
# 530000
# 535000
# 540000
# 545000
# 550000
# 555000
# 560000
# 565000
# 570000
# 575000
# 580000
# 585000
# 590000
# 595000
s_data_ = np.vstack(np.vstack(processed_data[:, 0])[:, 0])
print(s_data_.shape)
for dim in range(s_data_.shape[1]):
    m=np.mean(s_data_.T[dim])
    std=np.std(s_data_.T[dim])
    print(m, std)
# Out:
# (2000000, 13)
# 1.8686582334339619e-06 0.9999998507643622
# -2.4639355251565576e-07 0.9999999950204411
# -4.595727659761905e-09 0.9999999821096723
# -4.5366433914750816e-07 0.9999997699966466
# -2.204909804277122e-06 0.9999998351194488
# 1.1278330930508674e-06 0.999999968002415
# -7.116793422028423e-07 1.000000074067488
# -8.381691659451462e-07 1.0000000165879883
# -9.850711794570089e-07 1.0000000129900921
# -1.0246529411688242e-06 0.9999998988183882
# 1.6689601143298204e-06 0.9999999952550426
# 4.219667171128094e-07 1.0000000826999862
# 4.703746089944616e-07 1.0000001693371248
# (2000000, 17)
# -2.1728396859543863e-17 0.9999999999999999
# -8.15063572190411e-17 1.0
# -1.9802826045633992e-17 1.0
# 4.290257038519485e-17 1.0000000000000007
# -1.7633539073358405e-16 1.0
# 2.7156943360751028e-17 1.0000000000000004
# 6.087930159992538e-17 0.9999999999999996
# -5.1514348342607266e-17 0.9999999999999997
# 4.02610567107331e-15 0.9999999999999998
# -3.9584335809195184e-17 0.9999999999999999
# 1.1866063687193673e-17 1.0000000000000004
# 2.112532371256748e-17 0.9999999999999997
# 4.366285111245816e-18 1.0000000000000002
# 2.7540636438061484e-17 0.9999999999999998
# 9.947598300641402e-19 1.0000000000000004
# -8.760991931922035e-18 0.9999999999999998
# 1.6076029396572268e-17 1.0

# %%
# mean and std of s_ after normalization
s_data_ = np.vstack(processed_data[:10000, 1])
print(s_data_.shape)
for dim in range(s_data_.shape[1]):
    m=np.mean(s_data_.T[dim])
    std=np.std(s_data_.T[dim])
    print(m, std)
# Out:
# (10000, 17)
# 0.08555680165597819 0.8721940713675053
# -0.06583042420156335 0.28240378059307575
# -0.01840359500613393 0.9801188498299097
# 0.019547307029729743 1.0220002487881414
# -0.025462563526162135 0.998578887175435
# -0.041961980726741434 1.0030439179966222
# -0.002584885642055778 0.9476105470236046
# -0.013875349325193458 1.0161717865736244
# -0.15411494483982913 0.902800157424548
# 0.009026645766895991 0.9760137612679235
# 0.0001749432736522749 1.00098502055457
# -0.005509126597781656 0.9788140969799617
# -0.00034104549505959537 1.009393558714101
# -0.014572998649354855 1.006378224310072
# 0.000601332984724414 1.0063055086058048
# -0.002331900426126853 0.9670543661333147
# -0.00812206689886112 1.021966335915928

# %%
f = np.load(prefix+'norm_factor.npy')
print(f)
# Out:
# [[1.00032426e-01 9.99815017e-02 9.99957845e-02 1.00418597e-01
#   1.00372262e-01 1.00028450e-02 1.00849690e-02 2.48040274e-01
#   2.51164049e-01 2.45028690e-01 2.47608066e-01 2.52690077e-01
#   2.47275919e-01 2.54883468e-01 9.00162101e-01 4.47824538e-01
#   1.98954388e-01 5.01874566e-01 1.00441315e+02 5.98226881e+00]
#  [2.30298154e-02 2.30887458e-02 2.32770629e-02 2.29165014e-02
#   2.27435436e-02 2.30189203e-03 2.30188621e-03 1.44869789e-01
#   1.42086178e-01 1.44656897e-01 1.42573476e-01 1.42428443e-01
#   1.43827200e-01 1.44211441e-01 5.79494685e-02 2.02678382e-01
#   5.77539690e-02 2.90344089e-01 2.87544136e+01 2.32202840e+00]]

# %%
test_data = np.load(prefix+'test_dynamics.npy', allow_pickle=True)
s_dim = 25 # for halfcheetah
idx=5
sa = test_data[idx]['sa']
s_ = test_data[idx]['s_']
sa = np.vstack(sa)
# print(output_m_std(s_))
print(sa[:, :s_dim].shape, s_m_vec.shape)
sa = np.concatenate([(sa[:, :s_dim] - s_m_vec)/s_std_vec, sa[:, s_dim:]], axis=-1)
s_ = (s_ - s__m_vec)/s__std_vec

def output_m_std(data):
    data = np.array(data)
    for i in range(data.shape[1]):
        d=data.T[i]
        print(np.mean(d), np.std(d))
        
print(output_m_std(sa[:, :s_dim]))
print(output_m_std(s_))
# Out:
# (30000, 25) (25,)
# 0.07275864711601289 1.0642075096321066
# 0.02253192414928782 0.890338203864644
# 0.2065249755722175 0.8924293753204098
# 0.03477596953267736 0.9270480762588028
# -0.022727654835551014 1.0571191888526887
# 0.01154114108578656 1.0037987106361674
# 0.05819769663604091 0.8803652815716839
# -0.43003296964216475 0.8486230527588139
# -0.03003534685483894 1.0226669766568892
# -0.2673488720255028 1.0979697883645911
# -0.23525995761276203 1.050269979500093
# -0.0505795750867387 0.9889767760407141
# 0.27465731158960394 0.8859701729904914
# 0.0244577500498766 0.9416104319377915
# -0.022312330371990825 1.0135043002278754
# 0.013299239919842623 0.9889140816926828
# -0.03117132677277754 0.9340630193148894
# -0.029850955495903504 1.1111296487255682
# 0.04612452482364979 1.0173077955389693
# 0.014444157499559535 1.006719421529708
# 0.24648726384946035 0.46269376345608426
# -0.25061868306929175 0.8593895632808404
# 0.10800022232893032 0.8477545499130408
# -0.2065249755722448 0.8924293753204094
# 0.10852042479744686 0.9506148876579475
# None
# 0.07326087642294864 1.064176637287393
# 0.02225148917639928 0.8902309393682443
# 0.20815781176290923 0.8916097897069655
# 0.03477815123520092 0.9270356578674552
# -0.022725448478014058 1.0570998441395263
# 0.011547837842192913 1.003792325855849
# 0.058609069075679435 0.8793551196250963
# -0.43434301800718994 0.8475875387494121
# -0.029994708050734318 1.022767096785373
# -0.26781439774630933 1.0975147338510232
# -0.23569151359838605 1.049714557723089
# -0.05032182757304797 0.9889513263066002
# 0.2750757597008036 0.8850494334370149
# 0.024404116975126556 0.941559350177553
# -0.022327407300361403 1.0135022643961373
# 0.013358405117856261 0.9888709827022955
# -0.031159637494646803 0.9340550960095861
# -0.02981950081419567 1.11104001721525
# 0.04612165014629949 1.017275416932219
# 0.01438253649735948 1.0066867122593253
# 0.2477150203003315 0.45360211812007867
# -0.25278938586033456 0.8581099971882951
# 0.10833856821175482 0.847634663776271
# -0.20815781176287393 0.8916097897069657
# 0.10845467186575687 0.9506554468144568
# None
